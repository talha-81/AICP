# %% [markdown]
# # AICP Intership Task Week 4

# %% [markdown]
#  McDonald's Menu Nutritional Facts Analysis

# %% [markdown]
# ## Question no 1
#
# Import libraries (Numpy, pandas, matplotlib, plotly and seaborn) and then read csv file.
#
# ### Answer

# %% [markdown]
# ### Import Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import plotly.express as px
import plotly.graph_objects as go
import seaborn as sns

# %% [markdown]
# ### Reading CSV File

# %%
df = pd.read_csv('menu.csv')
df.head()
# Out:
#     Category                              Item    Serving Size  Calories  \
# 0  Breakfast                      Egg McMuffin  4.8 oz (136 g)       300
# 1  Breakfast                 Egg White Delight  4.8 oz (135 g)       250
# 2  Breakfast                  Sausage McMuffin  3.9 oz (111 g)       370
# 3  Breakfast         Sausage McMuffin with Egg  5.7 oz (161 g)       450
# 4  Breakfast  Sausage McMuffin with Egg Whites  5.7 oz (161 g)       400
#
#    Calories from Fat  Total Fat  Total Fat (% Daily Value)  Saturated Fat  \
# 0                120       13.0                         20            5.0
# 1                 70        8.0                         12            3.0
# 2                200       23.0                         35            8.0
# 3                250       28.0                         43           10.0
# 4                210       23.0                         35            8.0
#
#    Saturated Fat (% Daily Value)  Trans Fat  ...  Carbohydrates  \
# ...

# %% [markdown]
# ### Dealing With the specified Columns

# %%
attributes = df[['Calories', 'Total Fat', 'Carbohydrates', 'Dietary Fiber',
                'Sugars', 'Protein', 'Vitamin A (% Daily Value)', 'Vitamin C (% Daily Value)',
                'Calcium (% Daily Value)', 'Iron (% Daily Value)']]
attributes.head()
# Out:
#    Calories  Total Fat  Carbohydrates  Dietary Fiber  Sugars  Protein  \
# 0       300       13.0             31              4       3       17
# 1       250        8.0             30              4       3       18
# 2       370       23.0             29              4       2       14
# 3       450       28.0             30              4       2       21
# 4       400       23.0             30              4       2       21
#
#    Vitamin A (% Daily Value)  Vitamin C (% Daily Value)  \
# 0                         10                          0
# 1                          6                          0
# 2                          8                          0
# 3                         15                          0
# 4                          6                          0
#
#    Calcium (% Daily Value)  Iron (% Daily Value)
# 0                       25                    15
# 1                       25                     8
# 2                       25                    10
# ...

# %% [markdown]
# ## Question No 2
#
# Check statistical facts by checking all columns. Then calculate the maximum value of the following
# attributes ['Calories', 'Total Fat', 'Carbohydrates', 'Dietary Fiber', 'Sugars', 'Protein', 'Vitamin A (%
# Daily Value)', 'Vitamin C (% Daily Value)', 'Calcium (% Daily Value)', 'Iron (% Daily Value)']
#
# ### Answer

# %%
# Checking the statistical facts

statistical_facts = attributes.describe()

print("Statistical Facts:")
statistical_facts
# Out:
# Statistical Facts:
#           Calories   Total Fat  Carbohydrates  Dietary Fiber      Sugars  \
# count   260.000000  260.000000     260.000000     260.000000  260.000000
# mean    368.269231   14.165385      47.346154       1.630769   29.423077
# std     240.269886   14.205998      28.252232       1.567717   28.679797
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%     210.000000    2.375000      30.000000       0.000000    5.750000
# 50%     340.000000   11.000000      44.000000       1.000000   17.500000
# 75%     500.000000   22.250000      60.000000       3.000000   48.000000
# max    1880.000000  118.000000     141.000000       7.000000  128.000000
#
#           Protein  Vitamin A (% Daily Value)  Vitamin C (% Daily Value)  \
# count  260.000000                 260.000000                 260.000000
# mean    13.338462                  13.426923                   8.534615
# std     11.426146                  24.366381                  26.345542
# ...

# %%
# Calculating the maximum value for nutrients

max_values = attributes.max()

print("\nMaximum Values for Specified Attributes:")
max_values
# Out:
# Maximum Values for Specified Attributes:
# Calories                     1880.0
# Total Fat                     118.0
# Carbohydrates                 141.0
# Dietary Fiber                   7.0
# Sugars                        128.0
# Protein                        87.0
# Vitamin A (% Daily Value)     170.0
# Vitamin C (% Daily Value)     240.0
# Calcium (% Daily Value)        70.0
# Iron (% Daily Value)           40.0
# dtype: float64

# %% [markdown]
# ## Question No 3
#
# Check to see if infact there is any correlation between Calories and other independent variables by
# plotting a correlation matrix next.
#
# ### Answer

# %%
plt.figure(figsize=(8,6))
sns.heatmap(attributes.corr())
plt.title('correlation between Calories and other attributes')
plt.show()

# %% [markdown]
# ## Question No 4
# Draw boxplot for Calories vs Category to spot outliers and max calories category
# ### Answer

# %%
plt.figure(figsize=(8,6))
sns.boxplot(x='Calories',y='Category',data=df,hue='Category')
plt.title('boxplot for Calories vs Category')
plt.xlabel('Calories')
plt.ylabel('Category')
plt.legend(title='Category')
plt.show()

# %% [markdown]
# # Question No 5
# Figure out which exact item contains a high quantity for **['Calories', 'Total Fat', 'Carbohydrates',
# 'Dietary Fiber', 'Sugars', 'Protein', 'Vitamin A (% Daily Value)', 'Vitamin C (% Daily Value)', 'Calcium
# (% Daily Value)', 'Iron (% Daily Value)'.**
# Display summary link this:
# ### Answer

# %%
for i in attributes:
    maximum = max(df[i])
    max_index = df[i].idxmax()
    print(i+':   '+df["Item"][max_index]+' - '+str(maximum))
# Out:
# Calories:   Chicken McNuggets (40 piece) - 1880
# Total Fat:   Chicken McNuggets (40 piece) - 118.0
# Carbohydrates:   Chocolate Shake (Large) - 141
# Dietary Fiber:   Big Breakfast with Hotcakes (Large Biscuit) - 7
# Sugars:   McFlurry with M&M’s Candies (Medium) - 128
# Protein:   Chicken McNuggets (40 piece) - 87
# Vitamin A (% Daily Value):   Premium Bacon Ranch Salad (without Chicken) - 170
# Vitamin C (% Daily Value):   Minute Maid Orange Juice (Large) - 240
# Calcium (% Daily Value):   Strawberry Shake (Large) - 70
# Iron (% Daily Value):   Big Breakfast with Hotcakes (Regular Biscuit) - 40

# %% [markdown]
# ## Question No 6
# Draw Stripplot for each
# category against the following
# attributes **['Calories', 'Total Fat',
# 'Carbohydrates', 'Dietary
# Fiber', 'Sugars', 'Protein',
# 'Vitamin A (% Daily Value)',
# 'Vitamin C (% Daily Value)',
# 'Calcium (% Daily Value)', 'Iron
# (% Daily Value)'.**
# ### Answer

# %%
for i in attributes:
    plt.figure(figsize=(8,6))
    sns.stripplot(x='Category',y=i,data=df,jitter=True,palette='Set2')
    plt.title(f"{i} Content")
    plt.xlabel("Category")
    plt.ylabel(i)
    plt.xticks(rotation=45)
    plt.show()
# Out:
# C:\Users\PMLS\AppData\Local\Temp\ipykernel_2100\2095803617.py:3: FutureWarning: Passing `palette` without assigning `hue` is deprecated.
#   sns.stripplot(x='Category',y=i,data=df,jitter=True,palette='Set2')
# C:\Users\PMLS\AppData\Local\Temp\ipykernel_2100\2095803617.py:3: FutureWarning: Passing `palette` without assigning `hue` is deprecated.
#   sns.stripplot(x='Category',y=i,data=df,jitter=True,palette='Set2')
# C:\Users\PMLS\AppData\Local\Temp\ipykernel_2100\2095803617.py:3: FutureWarning: Passing `palette` without assigning `hue` is deprecated.
#   sns.stripplot(x='Category',y=i,data=df,jitter=True,palette='Set2')
# C:\Users\PMLS\AppData\Local\Temp\ipykernel_2100\2095803617.py:3: FutureWarning: Passing `palette` without assigning `hue` is deprecated.
#   sns.stripplot(x='Category',y=i,data=df,jitter=True,palette='Set2')
# C:\Users\PMLS\AppData\Local\Temp\ipykernel_2100\2095803617.py:3: FutureWarning: Passing `palette` without assigning `hue` is deprecated.
# ...

# %% [markdown]
# ## Question No 7
# Draw a horizontal bar graph for items in each **category** against the calories.
# Here is one sample for all items in **Beef & Pork**, you have to do it for items in each category. Also, write
# your observation.
# ### Answer

# %%
cat =df["Category"].unique()
for i in cat:
    plt.figure(figsize=(20,20))
    cat_df = df[df['Category'] == i].sort_values(by='Calories',ascending=False)
    plt.barh(cat_df['Item'],cat_df['Calories'] )
    plt.xlabel('Calories')
    plt.ylabel('Item')
    plt.title(f"Calories of Items in {i}")
    plt.gca().invert_yaxis()
    plt.show()

# %% [markdown]
# ## Observation
# - The analysis of the McDonald's menu dataset showcases a comprehensive approach to understanding the nutritional content of various menu items.
# - By leveraging Python libraries and data analysis techniques, it becomes possible to derive valuable insights into the calorie content, fats, carbohydrates, fibers, sugars, proteins, and essential vitamins and minerals present in the menu items.
# - This analysis can aid in making informed dietary choices and understanding the nutritional composition of fast-food offerings.
